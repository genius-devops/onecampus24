# %%
# COHORT 23 AND COHORT 24 PYTHON ACADEMY PROJECT 
# PROJECT RELEASE DATE: FEB 2, 2024 

# Your friend operates a grocery store and has asked you to design and implement a 
# Python-based Calculator script packaged as a function. The following are the 
# specifications he has given you. 
# 1. The function should have no arguments or input parameters. 
# 2. When called, the function should: 
# a. Prompt the user to select a compute function.   
# i. Multiplication 
# ii. Addition 
# iii. Division 
# iv. Subtraction 
# v. Exponential 
# vi. Square Root 
# vii. Floor Division (Quotient) 
# viii. Modulus operation (Remainder) 
# ix. Combination of Operations (Multi-Operation) 
# x. Mean of a list 
# xi. Sum of a list 
# xii. Median value of a list 
# xiii. Multiplication of a list 
# b. Prompt the user to provide Operands (values to compute) 
# i. The calculator should be able to accept single values (e.g. 4 + 9) 
# ii. The Calculator should also be able to accept as input, a list of values 
# separated by comma as Operand. 
# iii. operand. (e.g., sum of the list [2,4,5,6, 45,21] 
# c. The Calculator should process the input and print out the results to screen. 
# 3. The calculator should have a memory capability to store the input and results of 
# the last 10 computations done on it. 
# a. The user should be able to recall any of the last 10 calculations done on it 
# 4. Package this calculation as a compact function 
# Project Due Date: Friday February, 23, 2024

# %%
# solution 


def cal():
    pass

# %%
# Computations
# The concept of a Calculator

# Building the calculator as a function

# Example 1 using a function that does not receive input parameters when called

def Calculator():
    
    # Receieve user input
    func = input('specify the computation type: m--> Multiplication')
    val1 = input('provide the first value')
    val2 = input('provide the second value')
    
    # convert all numeric inputs to float
    val1 = float(val1)
    val2 = float(val2)
    if func == 'm' or func == 'M' or func == 'Multiplication' or func[0] == 'm':
        
        compVal = val1 * val2
        print(compVal)
    else:
        print('check your inputs and func spelling')
        Calculator()
   
    


func = 'multiplcasionnn'  # string
func[1]
def Calculator2(val1, val2,func):
    compVal = ''
    if func =='Add':
        compVal = val1 + val2
    elif func == 'Div':
        compVal = val1 / val2
        
    else:
        print('unknown operator')
    
    print(compVal)

num1 = 30
num2 = 20
opr = 'Sub'

Calculator2(num1, num2,opr)

# Building the calculator as a function

# Example 1 using a functin that does not recieve input parameters when called

def Calculator4():
    calcFeatures = """ This caluculator cam carry out the following operations:
    1. Multiplication: To mulitply , please specify 'M' or 1
    2. Addition: to get the sum of values please specify 'A' or 2
    3. Square of Value: to get the square of a vule pleas specify 'Sq' or 3
    """
    print(calcFeatures)
    # Recieve user intenet and input
    opr = input('specify operation: M or 1, A or 2, SQ or 3')
    
    if opr == 'M' or opr == '1':
        print('ready to execute multiplication. provide input values')
        vals = input('specify input values seperated by comma')
        valComponents = vals.split(',')
        print(f'you provided  {len(valComponents)} values for computation')
        numVals = [float(x.strip()) for x in valComponents]
        print(numVals)
        
        res = 1
        for val in numVals:
            res = res*val 
        print(res)

    elif opr == 'A' or opr == '2':
        print('ready to execute Addition. provide input values')
        vals = input('specify input values seperated by comma')

        valComponents = vals.split(',')
        print(f'you provided  {len(valComponents)} values for computation')
        numVals = [float(x.strip()) for x in valComponents]
        print(numVals)
        res = sum(numVals)            
        print(res)
        
        
    elif opr == 'SQ' or opr == '3':
        print('ready to find the square of a value. provide a SINGLE value')
        vals = input('provide a SINGLE value')
        if ',' in vals:
            print('please provide a single number to square')
            Calculator4()
        else:
            vals = vals.strip()
            vals = float(vals)
            sqVal = vals * vals

            print(sqVal)
    else:
        print('operation unknown')
        
        

   
Calculator4()

x = '23 34 56 78'
type(x)
x.split(' ')
type(x)
j =x.split(',')
type(j)
j[0]
z = x.strip()
type(z)
z
j
print(type(j))
xx = [2,3,4,5]
j = 0
[(j+=x) for x in xx]
x = 1
y =2

j = x+=y
j = [2,3,4]
[x*x for x in j]
x
j
x = [10,10,10]


j = 1

for val in x:
    j = j*val
    
print(j)



x = [10,5,8,2]


print(x.pop())
x = [2,3,4,5]
sum(x)
list1 = [4,5,7,9,3]

[x*2 for x in list1]
xList = []
for x in list1:
    xList.append(x*2)
print(xList)
# complex number

j = 5x +2c

def testFunc(x, y):
    j = x*y
    
    print(j)
    #return j

testFunc(4,5)
f = 2 * testFunc(4,5)
f
